# %% [markdown]
# ## Project 3
#
# This is a collaborative project conducted by the Fall 2017 students of DATA 620 at The City University of New York, in partial fulfillment of the requirements for the MS in Data Science degree.
#
# ### Problem Description
#
# This is a Team Project! For this project, please work with the entire class as one collaborative group! Your project should be submitted (as an IPython Notebook via GitHub) by end of day on Monday, October 25th. The group should present their code and findings in our meet-up on Tuesday October 26th. The ability to be an effective member of a virtual team is highly valued in the data science job market.
# Using any of the three classifiers described in chapter 6 of Natural Language Processing with Python, and any features you can think of, build the best name gender classifier you can. Begin by splitting the Names Corpus into three subsets: 500 words for the test set, 500 words for the dev-test set, and the remaining 6900 words for the training set. Then, starting with the example name gender classifier, make incremental improvements. Use the dev-test set to check your progress. Once you are satisfied with your classifier, check its final performance on the test set. How does the performance on the test set compare to the performance on the dev-test set? Is this what you'd expect?
#
# Source: Natural Language Processing with Python, exercise 6.10.2.
#
# ### Contributors Include
#
# * Joy Payton
# * Keith Folsom
# * Sonya Hong
#
#
# ### First, Obtain the Corpus
#
# Note: If not already executed, nltk.download() will allow you access to the names corpus

# %%
import nltk
from nltk.corpus import names
import random
import numpy as np
from nltk.metrics import *
import re
    

import string
from textstat.textstat import textstat
#nltk.download('names')

# %%
names = ([(name, 'male') for name in names.words('male.txt')] + \
         [(name, 'female') for name in names.words('female.txt')])

#names = random.shuffle(names)

# %%
random.shuffle(names)

# let's see what the randomly shuffles names look like
names[1:10]
# Out:
# [('TeresaAnne', 'female'),
#  ('Gene', 'female'),
#  ('Penelopa', 'female'),
#  ('Eudora', 'female'),
#  ('Ursuline', 'female'),
#  ('Ray', 'male'),
#  ('Carlena', 'female'),
#  ('Deny', 'female'),
#  ('Linoel', 'male')]

# %% [markdown]
# ### Create three subsets for development and error analysis of the models.
#
# ##### Development set:
# * 6900 names for the training set
# * 500 names for the dev-test set
#
# ##### Test set:
# * 500 names for the testing set

# %%
test_names, devtest_names, train_names = names[0:500], names[500:1000], names[1000:]

# %%
# Confirm the size of the three subsets
print("Training Set = {}".format(len(train_names)))
print("Dev-Test Set = {}".format(len(devtest_names)))
print("Test Set = {}".format(len(test_names)))
# Out:
# Training Set = 6944
# Dev-Test Set = 500
# Test Set = 500

# %% [markdown]
# ### Feature Extractor Functions
#
# This section below is to incrementallly improve the feature extraction functions which are subsequently applied to the development and test datasets.

# %%
# book example
def gender_features(name):
    return {'last_letter': name[-1]}

# most names beginning with a vowel are associated with females
def gender_features2(name):
    return {'first_letter': name[0]}

# from the book feature extractor that overfits 
def gender_features3(name):
    features = {}
    features["firstletter"] = name[0].lower()
    features["lastletter"] = name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count(%s)" % letter] = name.lower().count(letter)
        features["has(%s)" % letter] = (letter in name.lower())
    return features

## from the book
def gender_features4(name):
    return {"suffix1": name[-1:], "suffix2": name[-2:]}

# %%
gender_features3('amber')
gender_features4('amber')
# Out:
# {'suffix1': 'r', 'suffix2': 'er'}

# %% [markdown]
# ### Helper Functions

# %%
# Generic function to generate an error list based the arguments provided
# Accepts the classifer, names dataset, and the extractor function
# Returns the list of errors

def generate_errors(classifier, dataset, extractor_function): 
    
    errors = [] 

    for (name, tag) in dataset:
        guess = classifier.classify(extractor_function(name)) 
        if guess != tag: 
            errors.append((tag, guess, name))
            
    return errors

# %%
# Generic function to display classification errors
# Accepts the error list and an optional argument to show only n number of errors

def show_errors(errors, n=None):
   
    if n is not None: errors = errors[:n]
            
    for (tag, guess, name) in sorted(errors): 
        print('correct=%-8s guess=%-8s name=%-30s' %(tag, guess, name))

# %%
[(gender_features(n), g)  for (n, g) in train_names]
# Out:
# [({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'b'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'x'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'j'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'z'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'x'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'x'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'b'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'z'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'z'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'v'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'x'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'b'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ...]

# %% [markdown]
# ### Gender Identification Models (Try Some Models)

# %% [markdown]
# ###  NaiveBayes
# #### Gender Classification Model 1

# %%
# apply the first gender_feature extractor function from the book the the three datasets
train_set = [(gender_features(n), g)  for (n, g) in train_names]
devtest_set = [(gender_features(n), g)  for (n, g) in devtest_names]
test_set = [(gender_features(n), g)  for (n, g) in test_names]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# Examine the likelihood ratios
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     35.4 : 1.0
#              last_letter = 'k'              male : female =     27.9 : 1.0
#              last_letter = 'f'              male : female =     15.3 : 1.0
#              last_letter = 'p'              male : female =      9.9 : 1.0
#              last_letter = 'd'              male : female =      9.2 : 1.0

# %%
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.794

# %%
# display the classification errors
# calls the helper functions above
show_errors(generate_errors(classifier, devtest_names, gender_features))
# Out:
# correct=female   guess=male     name=Adel
# correct=female   guess=male     name=Aleen
# correct=female   guess=male     name=Alexis
# correct=female   guess=male     name=Allison
# correct=female   guess=male     name=Allyn
# correct=female   guess=male     name=Amber
# correct=female   guess=male     name=Babs
# correct=female   guess=male     name=Caitlin
# correct=female   guess=male     name=Caril
# correct=female   guess=male     name=Charmion
# correct=female   guess=male     name=Charo
# correct=female   guess=male     name=Christen
# correct=female   guess=male     name=Christian
# correct=female   guess=male     name=Chrystal
# correct=female   guess=male     name=Ciel
# correct=female   guess=male     name=Claribel
# correct=female   guess=male     name=Coralyn
# correct=female   guess=male     name=Devan
# correct=female   guess=male     name=Doll
# correct=female   guess=male     name=Dorcas
# correct=female   guess=male     name=Eryn
# correct=female   guess=male     name=Ethelin
# correct=female   guess=male     name=Floris
# correct=female   guess=male     name=Glynnis
# correct=female   guess=male     name=Gunvor
# correct=female   guess=male     name=Harriett
# correct=female   guess=male     name=Harriott
# correct=female   guess=male     name=Ingaborg
# correct=female   guess=male     name=Jacquelynn
# correct=female   guess=male     name=Janifer
# correct=female   guess=male     name=Jeniffer
# correct=female   guess=male     name=Jolyn
# correct=female   guess=male     name=Kara-Lynn
# correct=female   guess=male     name=Karel
# correct=female   guess=male     name=Karyl
# correct=female   guess=male     name=Katheryn
# correct=female   guess=male     name=Kaylyn
# correct=female   guess=male     name=Kim
# correct=female   guess=male     name=Linell
# correct=female   guess=male     name=Lust
# correct=female   guess=male     name=Madelin
# correct=female   guess=male     name=Margot
# correct=female   guess=male     name=Mariellen
# correct=female   guess=male     name=Marilin
# correct=female   guess=male     name=Marion
# correct=female   guess=male     name=Melisent
# correct=female   guess=male     name=Michell
# correct=female   guess=male     name=Mikako
# correct=female   guess=male     name=Miriam
# correct=female   guess=male     name=Noel
# correct=female   guess=male     name=Phylis
# correct=female   guess=male     name=Rachael
# correct=female   guess=male     name=Sharron
# correct=female   guess=male     name=Sharyl
# correct=female   guess=male     name=Sheryl
# correct=female   guess=male     name=Sibel
# correct=female   guess=male     name=Ted
# correct=female   guess=male     name=Teriann
# correct=female   guess=male     name=Velvet
# correct=male     guess=female   name=Ajai
# correct=male     guess=female   name=Alfie
# correct=male     guess=female   name=Ambrose
# correct=male     guess=female   name=Amery
# correct=male     guess=female   name=Amory
# correct=male     guess=female   name=Anatoly
# correct=male     guess=female   name=Andre
# correct=male     guess=female   name=Antoine
# correct=male     guess=female   name=Aubrey
# correct=male     guess=female   name=Bailey
# correct=male     guess=female   name=Bary
# correct=male     guess=female   name=Bay
# correct=male     guess=female   name=Bertie
# correct=male     guess=female   name=Bobby
# correct=male     guess=female   name=Broddie
# correct=male     guess=female   name=Bubba
# correct=male     guess=female   name=Cary
# correct=male     guess=female   name=Chevy
# correct=male     guess=female   name=Clarke
# correct=male     guess=female   name=Clive
# correct=male     guess=female   name=Cobbie
# correct=male     guess=female   name=Dave
# correct=male     guess=female   name=Doyle
# correct=male     guess=female   name=Georgy
# correct=male     guess=female   name=Gerome
# correct=male     guess=female   name=Giffy
# correct=male     guess=female   name=Greggory
# correct=male     guess=female   name=Hadleigh
# correct=male     guess=female   name=Harry
# correct=male     guess=female   name=Harvey
# correct=male     guess=female   name=Hurley
# correct=male     guess=female   name=Ikey
# correct=male     guess=female   name=Irvine
# correct=male     guess=female   name=Isadore
# correct=male     guess=female   name=Jeffry
# correct=male     guess=female   name=Jeremy
# correct=male     guess=female   name=Jessey
# correct=male     guess=female   name=Keefe
# correct=male     guess=female   name=Kermie
# correct=male     guess=female   name=Lane
# correct=male     guess=female   name=Marsh
# correct=male     guess=female   name=Mendie
# correct=male     guess=female   name=Moe
# correct=male     guess=female   name=Neddy
# correct=male     guess=female   name=Noe
# correct=male     guess=female   name=Rey
# correct=male     guess=female   name=Timothy
# correct=male     guess=female   name=Tome
# correct=male     guess=female   name=Torey
# correct=male     guess=female   name=Torry
# correct=male     guess=female   name=Tremayne
# correct=male     guess=female   name=Tully
# correct=male     guess=female   name=Udale
# correct=male     guess=female   name=Vasily
# correct=male     guess=female   name=Voltaire
# correct=male     guess=female   name=Ware
# correct=male     guess=female   name=Waverley
# correct=male     guess=female   name=Waverly
# correct=male     guess=female   name=Westley
# correct=male     guess=female   name=Zebedee

# %% [markdown]
# #### Gender Classification Model 2

# %%
# apply the gender_feature3 extractor function from the book the the three datasets

train_set = [(gender_features3(n), g)  for (n, g) in train_names]
devtest_set = [(gender_features3(n), g)  for (n, g) in devtest_names]
test_set = [(gender_features3(n), g)  for (n, g) in test_names]

classifier = nltk.NaiveBayesClassifier.train(train_set) 

## accuracy
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.788

# %%
# Examine the likelihood ratios
classifier.show_most_informative_features(20)
# Out:
# Most Informative Features
#               lastletter = 'a'            female : male   =     35.4 : 1.0
#               lastletter = 'k'              male : female =     27.9 : 1.0
#               lastletter = 'f'              male : female =     15.3 : 1.0
#               lastletter = 'p'              male : female =      9.9 : 1.0
#               lastletter = 'd'              male : female =      9.2 : 1.0
#               lastletter = 'v'              male : female =      9.2 : 1.0
#               lastletter = 'o'              male : female =      9.1 : 1.0
#                 count(v) = 2              female : male   =      8.4 : 1.0
#               lastletter = 'm'              male : female =      8.0 : 1.0
#               lastletter = 'r'              male : female =      6.6 : 1.0
#                 count(a) = 3              female : male   =      5.7 : 1.0
#               lastletter = 'w'              male : female =      5.5 : 1.0
#               lastletter = 'z'              male : female =      5.1 : 1.0
#               lastletter = 'g'              male : female =      4.9 : 1.0
#              firstletter = 'w'              male : female =      4.9 : 1.0
#                 count(w) = 1                male : female =      4.5 : 1.0
#                   has(w) = True             male : female =      4.5 : 1.0
#               lastletter = 's'              male : female =      4.0 : 1.0
#               lastletter = 't'              male : female =      4.0 : 1.0
#               lastletter = 'j'              male : female =      4.0 : 1.0

# %%
show_errors(generate_errors(classifier, devtest_names, gender_features3), 30)
# Out:
# correct=female   guess=male     name=Amber
# correct=female   guess=male     name=Ardyth
# correct=female   guess=male     name=Betsy
# correct=female   guess=male     name=Christen
# correct=female   guess=male     name=Dorcas
# correct=female   guess=male     name=Gerry
# correct=female   guess=male     name=Guenevere
# correct=female   guess=male     name=Gunvor
# correct=female   guess=male     name=Honey
# correct=female   guess=male     name=Margot
# correct=female   guess=male     name=Meridith
# correct=female   guess=male     name=Mikako
# correct=female   guess=male     name=Odette
# correct=female   guess=male     name=Tobie
# correct=female   guess=male     name=Wendy
# correct=female   guess=male     name=Wilhelmine
# correct=female   guess=male     name=Winni
# correct=male     guess=female   name=Aleks
# correct=male     guess=female   name=Anatoly
# correct=male     guess=female   name=Bailey
# correct=male     guess=female   name=Bay
# correct=male     guess=female   name=Bertie
# correct=male     guess=female   name=Blair
# correct=male     guess=female   name=Darryl
# correct=male     guess=female   name=Dell
# correct=male     guess=female   name=Gavriel
# correct=male     guess=female   name=Keefe
# correct=male     guess=female   name=Lane
# correct=male     guess=female   name=Sanson
# correct=male     guess=female   name=Udale

# %% [markdown]
# #### Gender Classification Model 3

# %%
# apply the gender_feature4 extractor function from the book the the three datasets

train_set = [(gender_features4(n), g)  for (n, g) in train_names]
devtest_set = [(gender_features4(n), g)  for (n, g) in devtest_names]
test_set = [(gender_features4(n), g)  for (n, g) in test_names]

classifier = nltk.NaiveBayesClassifier.train(train_set) 

## accuracy
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.81

# %%
# Examine the likelihood ratios
classifier.show_most_informative_features(20)
# Out:
# Most Informative Features
#                  suffix2 = 'na'           female : male   =    151.7 : 1.0
#                  suffix2 = 'la'           female : male   =     69.8 : 1.0
#                  suffix2 = 'ia'           female : male   =     37.8 : 1.0
#                  suffix1 = 'a'            female : male   =     35.4 : 1.0
#                  suffix2 = 'sa'           female : male   =     32.2 : 1.0
#                  suffix2 = 'ta'           female : male   =     29.4 : 1.0
#                  suffix1 = 'k'              male : female =     27.9 : 1.0
#                  suffix2 = 'us'             male : female =     26.4 : 1.0
#                  suffix2 = 'io'             male : female =     25.0 : 1.0
#                  suffix2 = 'do'             male : female =     25.0 : 1.0
#                  suffix2 = 'ra'           female : male   =     24.1 : 1.0
#                  suffix2 = 'ld'             male : female =     23.0 : 1.0
#                  suffix2 = 'rd'             male : female =     22.8 : 1.0
#                  suffix2 = 'rt'             male : female =     22.6 : 1.0
#                  suffix2 = 'os'             male : female =     17.2 : 1.0
#                  suffix1 = 'f'              male : female =     15.3 : 1.0
#                  suffix2 = 'ea'           female : male   =     14.6 : 1.0
#                  suffix2 = 'ka'           female : male   =     14.2 : 1.0
#                  suffix2 = 'ch'             male : female =     13.0 : 1.0
#                  suffix2 = 'rn'             male : female =     11.7 : 1.0

# %%
show_errors(generate_errors(classifier, devtest_names, gender_features4), 30)
# Out:
# correct=female   guess=male     name=Adel
# correct=female   guess=male     name=Allison
# correct=female   guess=male     name=Amber
# correct=female   guess=male     name=Ardyth
# correct=female   guess=male     name=Caril
# correct=female   guess=male     name=Charo
# correct=female   guess=male     name=Christen
# correct=female   guess=male     name=Dorcas
# correct=female   guess=male     name=Gerry
# correct=female   guess=male     name=Gunvor
# correct=female   guess=male     name=Jaleh
# correct=female   guess=male     name=Karel
# correct=female   guess=male     name=Linell
# correct=female   guess=male     name=Lisabeth
# correct=female   guess=male     name=Margot
# correct=female   guess=male     name=Meridith
# correct=male     guess=female   name=Ambrose
# correct=male     guess=female   name=Anatoly
# correct=male     guess=female   name=Aubrey
# correct=male     guess=female   name=Bailey
# correct=male     guess=female   name=Bertie
# correct=male     guess=female   name=Darryl
# correct=male     guess=female   name=Doyle
# correct=male     guess=female   name=Georgy
# correct=male     guess=female   name=Harvey
# correct=male     guess=female   name=Isadore
# correct=male     guess=female   name=Lane
# correct=male     guess=female   name=Tome
# correct=male     guess=female   name=Udale
# correct=male     guess=female   name=Waverly

# %% [markdown]
# ###  Decision Tree
# #### Gender Classification Model 4

# %%
# apply the first gender_feature extractor function from the book the the three datasets
train_set = [(gender_features(n), g)  for (n, g) in train_names]
devtest_set = [(gender_features(n), g)  for (n, g) in devtest_names]
test_set = [(gender_features(n), g)  for (n, g) in test_names]
classifier = nltk.DecisionTreeClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.794

# %%
# display the classification errors
# calls the helper functions above
show_errors(generate_errors(classifier, devtest_names, gender_features))
# Out:
# correct=female   guess=male     name=Anais
# correct=female   guess=male     name=Brett
# correct=female   guess=male     name=Camel
# correct=female   guess=male     name=Cameo
# correct=female   guess=male     name=Carlin
# correct=female   guess=male     name=Cloris
# correct=female   guess=male     name=Con
# correct=female   guess=male     name=Daloris
# correct=female   guess=male     name=Demeter
# correct=female   guess=male     name=Demetris
# correct=female   guess=male     name=Dew
# correct=female   guess=male     name=Ealasaid
# correct=female   guess=male     name=Emlyn
# correct=female   guess=male     name=Fawn
# correct=female   guess=male     name=Flo
# correct=female   guess=male     name=Gertrudis
# correct=female   guess=male     name=Harriet
# correct=female   guess=male     name=Honor
# correct=female   guess=male     name=Jackelyn
# correct=female   guess=male     name=Jaclin
# correct=female   guess=male     name=Jaclyn
# correct=female   guess=male     name=Jess
# correct=female   guess=male     name=Joslyn
# correct=female   guess=male     name=Karil
# correct=female   guess=male     name=Kiersten
# correct=female   guess=male     name=Lauren
# correct=female   guess=male     name=Leann
# correct=female   guess=male     name=Lurleen
# correct=female   guess=male     name=Maryellen
# correct=female   guess=male     name=Merl
# correct=female   guess=male     name=Nil
# correct=female   guess=male     name=Ninon
# correct=female   guess=male     name=Nitin
# correct=female   guess=male     name=Noreen
# correct=female   guess=male     name=Pier
# correct=female   guess=male     name=Raven
# correct=female   guess=male     name=Reiko
# correct=female   guess=male     name=Rhianon
# correct=female   guess=male     name=Ruthann
# correct=female   guess=male     name=Ryann
# correct=female   guess=male     name=Shannon
# correct=female   guess=male     name=Sharyl
# correct=female   guess=male     name=Sibel
# correct=female   guess=male     name=Suzann
# correct=female   guess=male     name=Tamar
# correct=female   guess=male     name=Wynn
# correct=male     guess=female   name=Alaa
# correct=male     guess=female   name=Alex
# correct=male     guess=female   name=Arnie
# correct=male     guess=female   name=Beale
# correct=male     guess=female   name=Bealle
# correct=male     guess=female   name=Berke
# correct=male     guess=female   name=Berkley
# correct=male     guess=female   name=Chrisy
# correct=male     guess=female   name=Clancy
# correct=male     guess=female   name=Cole
# correct=male     guess=female   name=Costa
# correct=male     guess=female   name=Cyrille
# correct=male     guess=female   name=Duke
# correct=male     guess=female   name=Ellsworth
# correct=male     guess=female   name=Felipe
# correct=male     guess=female   name=Filmore
# correct=male     guess=female   name=Freddie
# correct=male     guess=female   name=French
# correct=male     guess=female   name=Garvy
# correct=male     guess=female   name=Gay
# correct=male     guess=female   name=Griffith
# correct=male     guess=female   name=Guthrey
# correct=male     guess=female   name=Harry
# correct=male     guess=female   name=Hillary
# correct=male     guess=female   name=Hurley
# correct=male     guess=female   name=Ignace
# correct=male     guess=female   name=Jereme
# correct=male     guess=female   name=Jimmie
# correct=male     guess=female   name=Joey
# correct=male     guess=female   name=Joshuah
# correct=male     guess=female   name=Knox
# correct=male     guess=female   name=Louie
# correct=male     guess=female   name=Mace
# correct=male     guess=female   name=Maddie
# correct=male     guess=female   name=Moe
# correct=male     guess=female   name=Moore
# correct=male     guess=female   name=Murdoch
# correct=male     guess=female   name=Neddie
# correct=male     guess=female   name=Nickey
# correct=male     guess=female   name=Ossie
# correct=male     guess=female   name=Pace
# correct=male     guess=female   name=Pascale
# correct=male     guess=female   name=Pepe
# correct=male     guess=female   name=Prince
# correct=male     guess=female   name=Quincy
# correct=male     guess=female   name=Richie
# correct=male     guess=female   name=Ricki
# correct=male     guess=female   name=Scotty
# correct=male     guess=female   name=Shea
# correct=male     guess=female   name=Thorpe
# correct=male     guess=female   name=Toby
# correct=male     guess=female   name=Tye
# correct=male     guess=female   name=Uli
# correct=male     guess=female   name=Uriah
# correct=male     guess=female   name=Vite
# correct=male     guess=female   name=Voltaire
# correct=male     guess=female   name=Waine

# %% [markdown]
# #### Gender Classification Model 5

# %%
# apply the gender_feature3 extractor function from the book the the three datasets

train_set = [(gender_features3(n), g)  for (n, g) in train_names]
devtest_set = [(gender_features3(n), g)  for (n, g) in devtest_names]
test_set = [(gender_features3(n), g)  for (n, g) in test_names]

classifier = nltk.DecisionTreeClassifier.train(train_set)

## accuracy
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.818

# %%
show_errors(generate_errors(classifier, devtest_names, gender_features3), 30)
# Out:
# correct=female   guess=male     name=Ann-Mari
# correct=female   guess=male     name=Avivah
# correct=female   guess=male     name=Bobbi
# correct=female   guess=male     name=Con
# correct=female   guess=male     name=Demetris
# correct=female   guess=male     name=Flo
# correct=female   guess=male     name=Gerhardine
# correct=female   guess=male     name=Lauren
# correct=female   guess=male     name=Noreen
# correct=female   guess=male     name=Odille
# correct=female   guess=male     name=Oreste
# correct=female   guess=male     name=Wally
# correct=female   guess=male     name=Waly
# correct=male     guess=female   name=Alden
# correct=male     guess=female   name=Berke
# correct=male     guess=female   name=Clancy
# correct=male     guess=female   name=Cole
# correct=male     guess=female   name=Cyrille
# correct=male     guess=female   name=Filmore
# correct=male     guess=female   name=Frank
# correct=male     guess=female   name=Guthrey
# correct=male     guess=female   name=Harry
# correct=male     guess=female   name=Hillary
# correct=male     guess=female   name=Jean-Paul
# correct=male     guess=female   name=Judson
# correct=male     guess=female   name=Mylo
# correct=male     guess=female   name=Nickey
# correct=male     guess=female   name=Shea
# correct=male     guess=female   name=Skell
# correct=male     guess=female   name=Waine

# %% [markdown]
# #### Gender Classification Model 6

# %%
# apply the gender_feature4 extractor function from the book the the three datasets

train_set = [(gender_features4(n), g)  for (n, g) in train_names]
devtest_set = [(gender_features4(n), g)  for (n, g) in devtest_names]
test_set = [(gender_features4(n), g)  for (n, g) in test_names]

classifier = nltk.DecisionTreeClassifier.train(train_set)

## accuracy
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.83

# %%
show_errors(generate_errors(classifier, devtest_names, gender_features4), 30)
# Out:
# correct=female   guess=male     name=Con
# correct=female   guess=male     name=Flo
# correct=female   guess=male     name=Jaclin
# correct=female   guess=male     name=Leigh
# correct=female   guess=male     name=Mame
# correct=female   guess=male     name=Nil
# correct=female   guess=male     name=Pier
# correct=male     guess=female   name=Alden
# correct=male     guess=female   name=Arnie
# correct=male     guess=female   name=Chrisy
# correct=male     guess=female   name=Clancy
# correct=male     guess=female   name=Cole
# correct=male     guess=female   name=Cyrille
# correct=male     guess=female   name=Donn
# correct=male     guess=female   name=Dru
# correct=male     guess=female   name=Felipe
# correct=male     guess=female   name=Filmore
# correct=male     guess=female   name=Frank
# correct=male     guess=female   name=Garvy
# correct=male     guess=female   name=Guthrey
# correct=male     guess=female   name=Harry
# correct=male     guess=female   name=Hillary
# correct=male     guess=female   name=Nathanial
# correct=male     guess=female   name=Nickey
# correct=male     guess=female   name=Ossie
# correct=male     guess=female   name=Pace
# correct=male     guess=female   name=Quincy
# correct=male     guess=female   name=Shea
# correct=male     guess=female   name=Uriah
# correct=male     guess=female   name=Waine

# %% [markdown]
# ### Model Selection (Choose Best Candidate)
#
# #### Check the model's final performance on the test set.
#
# #### How does the performance on the test set compare to the performance on the dev-test set?
#
# #### Is this what you'd expect?

# %%
    
import re
import string
from textstat.textstat import textstat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-3ef704536099> in <module>()
#       3 import re
#       4 import string
# ----> 5 from textstat.textstat import textstat
#
# ModuleNotFoundError: No module named 'textstat'

# %%
class NLP_Classifier():
    def __init__(self,model):
        self.model = model
        #self.feat_num = feat_num
        
        #train_set = [(gender_features3(n), g)  for (n, g) in train_names]
        #devtest_set = [(gender_features3(n), g)  for (n, g) in devtest_names]
        #test_set = [(gender_features3(n), g)  for (n, g) in test_names]


    def get_features(self,name,feat_num):
        '''
        Parameters:
            name - string of name to extract feature
            feat_num - itterable colleciton of integers specifying features. *Defaults to 1:9 inclusive
                1: last letter
                2: first letter
                3: Vowel counts
                4: Hard consonant count
                5: Soft consonant count
                6: Syllable Count
                7: Name length
                8: Last two chars
                9: Last three chars
                10: char count --> feature for all alpha chars
                11: char present --> feature for all alpha chars (boolean)
        Returns:
            features: a dictionary of extracted features
        '''
        features = {}
        
        
        
        # Converts feat_num to itterable if type is int
        if type(feat_num) is int:
            feat_num = (0, feat_num)        
       
        # Gender Feature 1: Last letter - book example
        if 1 in feat_num:
            features['last_letter'] = name[-1].lower()
            
        # Gender Feature 2: First letter - most names beginning with a vowel --> females
        if 2 in feat_num:
            features['first_letter'] = name[0].lower()
            
        # Gender Feature 3: Vowel Counts
        if 3 in feat_num:
            features['vowel_count'] = len(re.sub(r'[^aeiou]', '', name.lower()))
            
        # Gender Feature 4: Hard consonants using general rules of c and g
        if 4 in feat_num:
            features['hard_consts'] = len(re.findall(r'[cg][^eiy]', name.lower()))/2
            
        # Gender Feature 5: Soft consonants using general rules of c and g
        if 5 in feat_num:
            features['soft_consts'] = len(re.findall(r'[cg][eiy]', name.lower()))/2
            
        # Gender Feature 6: Syllable Count of names via textstat
        if 6 in feat_num:
            features['syllable_count'] = textstat.syllable_count(name.lower())
    
        # Gender Feature 7: Name length
        if 7 in feat_num:
            features["length"] = len(name)
        
        # Gender Feature 8: Last two chars
        if 8 in feat_num:
            features["last2letters"] = name[-2:].lower()
            
        # Gender Feature 9: Last three chars
        if 9 in feat_num:
            features["last3letters"] = name[-3:].lower()
    
        # Gender Feature 10: Char Counts (overfitts)
        if 10 in feat_num:
            for letter in string.ascii_lowercase:
                features["count_{0}".format(letter)] = name.lower().count(letter)
                
        # Gender Feature 11: Char Booleans (overfitts)
        if 11 in feat_num:
            for letter in string.ascii_lowercase:
                features["has_{0}".format(letter)] = letter in name.lower()
        
        
        if 12 in feat_num:
            features = {}
            letters=list(map(chr, range(ord('a'), ord('z') + 1)))
            for letter in letters:
                features["count(%s)" % letter] = name.lower().count(letter)


        if 13 in feat_num:
            features = {}
            letters=list(map(chr, range(ord('a'), ord('z') + 1)))
            for letter1 in letters:
                for letter2 in letters:
                    features["has("+letter1+letter2+")"] = (letter1+letter2 in name.lower())

        if 14 in feat_num:
            features["first2Letters"]=name[0:2].lower()

        if 15 in feat_num:
            features = {}
            features["firstletter"] = name[0].lower()
            features["lastletter"] = name[-1].lower()
            features["last2letter"] = name[-2:].lower()
            features["last3letter"] = name[-3:].lower()

            letters=list(map(chr, range(ord('a'), ord('z') + 1)))
            for letter1 in letters:
                features["count("+letter1+")"] = name.lower().count(letter1)
                features["has("+letter1+")"] = (letter1 in name.lower())
                # iterate over 2-grams
                for letter2 in letters:

                    features["has("+letter1+letter2+")"] = (letter1+letter2 in name.lower())


        if 16 in feat_num:
            # define features
            features = {}
            # has(fo) = True
            features["has(fo)"] = ('fo' in name.lower())
            # has(hu) = True
            features["has(hu)"] = ('hu' in name.lower())
            # has(rv) = True
            features["has(rv)"] = ('rv' in name.lower())    
            # has(rw) = True
            features["has(rw)"] = ('rw' in name.lower()) 
            # has(sp) = True
            features["has(sp)"] = ('sp' in name.lower())

            # lastletter = 'a'
            features["lastletter=a"] = ('a' in name[-1:].lower())
            # lastletter = 'f'
            features["lastletter=f"] = ('f' in name[-1:].lower())
            # lastletter = 'k'
            features["lastletter=k"] = ('k' in name[-1:].lower())

            # last2letter = 'ch'
            features["last2letter=ch"] = ('ch' in name[-2:].lower())
            # last2letter = 'do'
            features["last2letter=do"] = ('do' in name[-2:].lower())
            # last2letter = 'ia'
            features["last2letter=ia"] = ('ia' in name[-2:].lower())
            # last2letter = 'im'
            features["last2letter=im"] = ('im' in name[-2:].lower())
            # last2letter = 'io'
            features["last2letter=io"] = ('io' in name[-2:].lower())
            # last2letter = 'la'
            features["last2letter=la"] = ('la' in name[-2:].lower())
            # last2letter = 'ld'
            features["last2letter=ld"] = ('ld' in name[-2:].lower())
            # last2letter = 'na'
            features["last2letter=na"] = ('na' in name[-2:].lower())
            # last2letter = 'os'
            features["last2letter=os"] = ('os' in name[-2:].lower())
            # last2letter = 'ra'
            features["last2letter=ra"] = ('ra' in name[-2:].lower())
            # last2letter = 'rd'
            features["last2letter=rd"] = ('rd' in name[-2:].lower())
            # last2letter = 'rt'
            features["last2letter=rt"] = ('rt' in name[-2:].lower())
            # last2letter = 'sa'
            features["last2letter=sa"] = ('sa' in name[-2:].lower())
            # last2letter = 'ta'
            features["last2letter=ta"] = ('ta' in name[-2:].lower())
            # last2letter = 'us'
            features["last2letter=us"] = ('us' in name[-2:].lower())

            # last3letter = 'ana'
            features["last3letter=ana"] = ('ana' in name[-3:].lower())    
            # last3letter = u'ard'
            features["last3letter=ard"] = ('ard' in name[-3:].lower())        
            # last3letter = u'ita'
            features["last3letter=ita"] = ('ita' in name[-3:].lower())    
            # last3letter = u'nne'
            features["last3letter=nne"] = ('nne' in name[-3:].lower())    
            # last3letter = u'tta'
            features["last3letter=tta"] = ('tta' in name[-3:].lower())    
        
        return features

    
    def show_errors(self, errors, n=None):
        if n is not None: errors = errors[:n]          
        for (tag, guess, name) in sorted(errors): 
            print('correct=%-8s guess=%-8s name=%-30s' %(tag, guess, name))
        return None 
    
    
    def classifier_report(self,classifier,dataset,feat_num):
        feat_num = int(feat_num)
        dataset_predictions = [classifier.classify(self.get_features(n,feat_num))  for (n, g) in dataset]
        dataset_gold = [g  for (n, g) in dataset]
        cm=ConfusionMatrix(dataset_gold, dataset_predictions)
        print(cm)
    
    def fit_model(self,feat_num):
       
        for i in np.arange(1,feat_num):
            feat_num =int(i)
            errors = [] 
            
            train_set = [(self.get_features(n,feat_num), g)  for (n, g) in train_names]
            devtest_set = [(self.get_features(n,feat_num), g)  for (n, g) in devtest_names]
            test_set = [(self.get_features(n,feat_num), g)  for (n, g) in test_names] 
            classifier = self.model.train(train_set) 
            
            # For errors list
            for (name, tag) in devtest_names:
                guess = classifier.classify(self.get_features(name,feat_num)) 
                if guess != tag: 
                    errors.append((tag, guess, name))    
                    
            # Print errors        
            self.show_errors(errors, 0)
            
            #Print classifier report
            self.classifier_report(classifier,train_names,i)
            
            # Only for NaiveBayes
            if self.model ==nltk.NaiveBayesClassifier:
                classifier.show_most_informative_features(5)
            
            print("Accuracy of model {} using feature {}:{}".format(self.model,feat_num,nltk.classify.accuracy(classifier, devtest_set)))

# %%
clf = NLP_Classifier(nltk.NaiveBayesClassifier)
clf.fit_model(16)
# Out:
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3594> 782 |
#   male |  859<1709>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#              last_letter = 'a'            female : male   =     32.3 : 1.0
#              last_letter = 'k'              male : female =     30.9 : 1.0
#              last_letter = 'f'              male : female =     28.9 : 1.0
#              last_letter = 'p'              male : female =     14.2 : 1.0
#              last_letter = 'v'              male : female =     10.5 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 1:0.78
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4173> 203 |
#   male | 2234 <334>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#             first_letter = 'w'              male : female =      4.5 : 1.0
#             first_letter = 'u'              male : female =      2.7 : 1.0
#             first_letter = 'q'              male : female =      2.6 : 1.0
#             first_letter = 'x'              male : female =      2.3 : 1.0
#             first_letter = 'h'              male : female =      2.3 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 2:0.666
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3875> 501 |
#   male | 2055 <513>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#              vowel_count = 5              female : male   =      4.0 : 1.0
#              vowel_count = 4              female : male   =      2.5 : 1.0
#              vowel_count = 1                male : female =      1.7 : 1.0
#              vowel_count = 2                male : female =      1.5 : 1.0
#              vowel_count = 3              female : male   =      1.5 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 3:0.634
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4371>   5 |
#   male | 2556  <12>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#              hard_consts = 1.0              male : female =      3.9 : 1.0
#              hard_consts = 0.5              male : female =      1.2 : 1.0
#              hard_consts = 0.0            female : male   =      1.0 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 4:0.64
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4376>   . |
#   male | 2568   <.>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#              soft_consts = 1.0            female : male   =      2.0 : 1.0
#              soft_consts = 0.5            female : male   =      1.1 : 1.0
#              soft_consts = 0.0              male : female =      1.0 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 5:0.638
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4376>   . |
#   male | 2568   <.>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#           syllable_count = 3.6            female : male   =      3.2 : 1.0
#           syllable_count = 2.7            female : male   =      2.1 : 1.0
#           syllable_count = 0.9              male : female =      1.5 : 1.0
#           syllable_count = 1.8              male : female =      1.1 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 6:0.638
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4260> 116 |
#   male | 2432 <136>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#                   length = 2                male : female =      2.4 : 1.0
#                   length = 3                male : female =      2.0 : 1.0
#                   length = 10             female : male   =      1.4 : 1.0
#                   length = 9              female : male   =      1.3 : 1.0
#                   length = 4                male : female =      1.2 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 7:0.64
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3928> 448 |
#   male |  909<1659>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#             last2letters = 'na'           female : male   =     93.5 : 1.0
#             last2letters = 'la'           female : male   =     70.5 : 1.0
#             last2letters = 'us'             male : female =     62.9 : 1.0
#             last2letters = 'ia'           female : male   =     38.1 : 1.0
#             last2letters = 'sa'           female : male   =     33.7 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 8:0.782
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4074> 302 |
#   male |  671<1897>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#             last3letters = 'nne'          female : male   =     33.6 : 1.0
#             last3letters = 'ard'            male : female =     28.4 : 1.0
#             last3letters = 'ita'          female : male   =     24.6 : 1.0
#             last3letters = 'ana'          female : male   =     23.7 : 1.0
#             last3letters = 'tta'          female : male   =     22.9 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 9:0.742
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3772> 604 |
#   male | 1413<1155>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#                  count_v = 2              female : male   =      8.4 : 1.0
#                  count_a = 3              female : male   =      4.4 : 1.0
#                  count_w = 1                male : female =      4.2 : 1.0
#                  count_l = 3              female : male   =      3.9 : 1.0
#                  count_f = 2                male : female =      3.9 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 10:0.7
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3795> 581 |
#   male | 1558<1010>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#                    has_w = True             male : female =      4.2 : 1.0
#                    has_u = True             male : female =      1.9 : 1.0
#                    has_f = True             male : female =      1.8 : 1.0
#                    has_p = True             male : female =      1.8 : 1.0
#                    has_o = True             male : female =      1.6 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 11:0.708
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3772> 604 |
#   male | 1413<1155>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#                 count(v) = 2              female : male   =      8.4 : 1.0
#                 count(a) = 3              female : male   =      4.4 : 1.0
#                 count(w) = 1                male : female =      4.2 : 1.0
#                 count(l) = 3              female : male   =      3.9 : 1.0
#                 count(f) = 2                male : female =      3.9 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 12:0.7
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3729> 647 |
#   male | 1006<1562>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#                  has(rv) = True             male : female =     29.0 : 1.0
#                  has(hu) = True             male : female =     23.5 : 1.0
#                  has(fo) = True             male : female =     21.5 : 1.0
#                  has(rw) = True             male : female =     17.6 : 1.0
#                  has(sp) = True             male : female =     16.5 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 13:0.764
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3946> 430 |
#   male | 1738 <830>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#            first2Letters = 'hu'             male : female =     16.2 : 1.0
#            first2Letters = 'ya'             male : female =     12.8 : 1.0
#            first2Letters = 'wa'             male : female =     11.5 : 1.0
#            first2Letters = 'tu'             male : female =     10.6 : 1.0
#            first2Letters = 'ce'           female : male   =      9.8 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 14:0.668
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3757> 619 |
#   male |  493<2075>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#              last2letter = 'na'           female : male   =     93.5 : 1.0
#              last2letter = 'la'           female : male   =     70.5 : 1.0
#              last2letter = 'us'             male : female =     62.9 : 1.0
#              last2letter = 'ia'           female : male   =     38.1 : 1.0
#              last2letter = 'sa'           female : male   =     33.7 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 15:0.81

# %%
clf = NLP_Classifier(nltk.DecisionTreeClassifier)

# %%
# Out:
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4376>   . |
#   male | 2568   <.>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 0:0.638
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<3594> 782 |
#   male |  859<1709>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#              last_letter = 'a'            female : male   =     32.3 : 1.0
#              last_letter = 'k'              male : female =     30.9 : 1.0
#              last_letter = 'f'              male : female =     28.9 : 1.0
#              last_letter = 'p'              male : female =     14.2 : 1.0
#              last_letter = 'v'              male : female =     10.5 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 1:0.78
#        |    f      |
#        |    e      |
#        |    m    m |
#        |    a    a |
#        |    l    l |
#        |    e    e |
# -------+-----------+
# female |<4173> 203 |
#   male | 2234 <334>|
# -------+-----------+
# (row = reference; col = test)
#
# Most Informative Features
#             first_letter = 'w'              male : female =      4.5 : 1.0
#             first_letter = 'u'              male : female =      2.7 : 1.0
#             first_letter = 'q'              male : female =      2.6 : 1.0
#             first_letter = 'x'              male : female =      2.3 : 1.0
#             first_letter = 'h'              male : female =      2.3 : 1.0
# Accuracy of model <class 'nltk.classify.naivebayes.NaiveBayesClassifier'> using feature 2:0.666

# %%
train_set_predictions = [classifier.classify(gender_features10(n))  for (n, g) in train_names]
train_set_gold = [g  for (n, g) in train_names]
cm=ConfusionMatrix(train_set_gold, train_set_predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-1912548040f8> in <module>()
# ----> 1 train_set_predictions = [classifier.classify(gender_features10(n))  for (n, g) in train_names]
#       2 train_set_gold = [g  for (n, g) in train_names]
#       3 cm=ConfusionMatrix(train_set_gold, train_set_predictions)
#
# <ipython-input-68-1912548040f8> in <listcomp>(.0)
# ----> 1 train_set_predictions = [classifier.classify(gender_features10(n))  for (n, g) in train_names]
#       2 train_set_gold = [g  for (n, g) in train_names]
#       3 cm=ConfusionMatrix(train_set_gold, train_set_predictions)
#
# NameError: name 'classifier' is not defined

# %%
train_set = [(gender_features(n), g)  for (n, g) in train_names]
devtest_set = [(gender_features(n), g)  for (n, g) in devtest_names]
test_set = [(gender_features(n), g)  for (n, g) in test_names]

# %%
train_set = [(clf.get_features(n,1), g)  for (n, g) in train_names]

# %%
class WithClass():
    def __init__(self):
        self.value = "Bob"
    def my_func(self):
        print(self.value)
    def test_class(self):
        my_func(self)

# %%
WithClass().my_func()
# Out:
# Bob

# %%
WithClass().test_class()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8917719194bc> in <module>()
# ----> 1 WithClass().test_class()
#
# <ipython-input-22-dce28befd08f> in test_class(self)
#       5         print(self.value)
#       6     def test_class(self):
# ----> 7         my_func(self)
#
# NameError: name 'my_func' is not defined

# %%
names[10]

def gender_fea(name):
    return {'last_letter': name[-1]}

# %%
names[10][0]
# Out:
# 'Aubry'

# %%
get_features(names[10][0],2)
#gender_fea(names[10][0])
# Out:
# {'first_letter': 'a'}

# %%
# Out:
# [('Anjela', 'female'),
#  ('Lane', 'male'),
#  ('Morganne', 'female'),
#  ('Mauricio', 'male'),
#  ('Lela', 'female'),
#  ('Hamil', 'male'),
#  ('Dorothy', 'female'),
#  ('Patrice', 'female'),
#  ('Broderic', 'male'),
#  ('Nonah', 'female'),
#  ('Aubry', 'female'),
#  ('Malory', 'female'),
#  ('Gonzalo', 'male'),
#  ('Shalom', 'male'),
#  ('Gilligan', 'female'),
#  ('Caro', 'female'),
#  ('Xymenes', 'male'),
#  ('Rosalie', 'female'),
#  ('Page', 'female'),
#  ('Catha', 'female'),
#  ('Xylia', 'female'),
#  ('Karita', 'female'),
#  ('Lita', 'female'),
#  ('Kylie', 'female'),
#  ('Brody', 'male'),
#  ('Binnie', 'female'),
#  ('Hannis', 'female'),
#  ('Betta', 'female'),
#  ('Johnna', 'female'),
#  ('Theressa', 'female'),
#  ('Ursulina', 'female'),
#  ('Fay', 'female'),
#  ('Yuri', 'male'),
#  ('Cherianne', 'female'),
#  ('Westbrook', 'male'),
#  ('Hallie', 'female'),
#  ('Kirbie', 'female'),
#  ('Marcellina', 'female'),
#  ('Aldo', 'male'),
#  ('Nicoline', 'female'),
#  ('Korrie', 'female'),
#  ('Bartholomeus', 'male'),
#  ('Charmane', 'female'),
#  ('Phillis', 'female'),
#  ('Chet', 'male'),
#  ('Uriah', 'male'),
#  ('Heida', 'female'),
#  ('Elisha', 'female'),
#  ('Nathaniel', 'male'),
#  ('Clarke', 'male'),
#  ('Acacia', 'female'),
#  ('Bridget', 'female'),
#  ('Marlene', 'female'),
#  ('Sarette', 'female'),
#  ('Trina', 'female'),
#  ('Aubrey', 'female'),
#  ('Daisy', 'female'),
#  ('Odessa', 'female'),
#  ('Jenilee', 'female'),
#  ('Pieter', 'male'),
#  ('Leonie', 'female'),
#  ('Auberta', 'female'),
#  ('Fiona', 'female'),
#  ('Thibaut', 'male'),
#  ('Etti', 'female'),
#  ('Johnette', 'female'),
#  ('Waring', 'male'),
#  ('Charlene', 'female'),
#  ('Hans-Peter', 'male'),
#  ('Blithe', 'female'),
#  ('Eulalie', 'female'),
#  ('Devin', 'male'),
#  ('Thayne', 'male'),
#  ('Kathryn', 'female'),
#  ('Esmeralda', 'female'),
#  ('Terry', 'male'),
#  ('Anne-Corinne', 'female'),
#  ('Miguel', 'male'),
#  ('Codee', 'female'),
#  ('Marilin', 'female'),
#  ('Len', 'male'),
#  ('Rory', 'male'),
#  ('Audy', 'female'),
#  ('Beverlie', 'female'),
#  ('Gregg', 'male'),
#  ('Georgeta', 'female'),
#  ('Marya', 'female'),
#  ('Chery', 'female'),
#  ('Emalia', 'female'),
#  ('Morley', 'male'),
#  ('Trista', 'female'),
#  ('Natasha', 'female'),
#  ('Eberhard', 'male'),
#  ('Wallie', 'female'),
#  ('Caesar', 'male'),
#  ('Vinod', 'male'),
#  ('Pavia', 'female'),
#  ('Derrek', 'male'),
#  ('Elric', 'male'),
#  ('Dora', 'female'),
#  ('Templeton', 'male'),
#  ('Geri', 'male'),
#  ('Devon', 'female'),
#  ('Fyodor', 'male'),
#  ('Kordula', 'female'),
#  ('Aurilia', 'female'),
#  ('Harald', 'male'),
#  ('Rhoda', 'female'),
#  ('Jordan', 'female'),
#  ('Merle', 'female'),
#  ('Charin', 'female'),
#  ('Angeline', 'female'),
#  ('Layla', 'female'),
#  ('Ninetta', 'female'),
#  ('Petronia', 'female'),
#  ('Linnie', 'female'),
#  ('Margot', 'female'),
#  ('Renato', 'male'),
#  ('Ulrike', 'female'),
#  ('Zerk', 'male'),
#  ('Zared', 'male'),
#  ('Darice', 'female'),
#  ('Rosa', 'female'),
#  ('Lex', 'male'),
#  ('Noelani', 'female'),
#  ('Carmelle', 'female'),
#  ('Chantal', 'female'),
#  ('Johannes', 'male'),
#  ('Kali', 'female'),
#  ('Jarrett', 'male'),
#  ('Pansy', 'female'),
#  ('Row', 'female'),
#  ('Glenda', 'female'),
#  ('Neilla', 'female'),
#  ('Horst', 'male'),
#  ('Evania', 'female'),
#  ('Doroteya', 'female'),
#  ('Siouxie', 'female'),
#  ('Briney', 'female'),
#  ('Callie', 'female'),
#  ('Gerrilee', 'female'),
#  ('Maudie', 'female'),
#  ('Bob', 'male'),
#  ('Cammy', 'female'),
#  ('Cornelle', 'female'),
#  ('Rudyard', 'male'),
#  ('Kurt', 'male'),
#  ('Riccardo', 'male'),
#  ('Marleah', 'female'),
#  ('Pip', 'male'),
#  ('Felice', 'female'),
#  ('Gussie', 'female'),
#  ('Honey', 'female'),
#  ('Neal', 'male'),
#  ('Frankie', 'female'),
#  ('Tedmund', 'male'),
#  ('Elysha', 'female'),
#  ('Jesselyn', 'female'),
#  ('Lotte', 'female'),
#  ('Beitris', 'female'),
#  ('Michelle', 'female'),
#  ('Lotta', 'female'),
#  ('Darla', 'female'),
#  ('Obadiah', 'male'),
#  ('Roz', 'female'),
#  ('Heddi', 'female'),
#  ('Mustafa', 'male'),
#  ('Corrianne', 'female'),
#  ('Whit', 'male'),
#  ('Myrlene', 'female'),
#  ('Carmine', 'female'),
#  ('Beilul', 'female'),
#  ('Constantine', 'female'),
#  ('Avril', 'female'),
#  ('Mallorie', 'female'),
#  ('Derrol', 'male'),
#  ('Barnaby', 'male'),
#  ('Kimbra', 'female'),
#  ('Hally', 'female'),
#  ('Tabby', 'male'),
#  ('Arne', 'male'),
#  ('Donia', 'female'),
#  ('Myrta', 'female'),
#  ('Stephani', 'female'),
#  ('Clive', 'male'),
#  ('Merv', 'male'),
#  ('Teodoro', 'male'),
#  ('Tyler', 'male'),
#  ('Gordan', 'male'),
#  ('Llewellyn', 'male'),
#  ('Karlotta', 'female'),
#  ('Rozella', 'female'),
#  ('Sharleen', 'female'),
#  ('Ines', 'female'),
#  ('Shaylynn', 'female'),
#  ('Avraham', 'male'),
#  ('Dedra', 'female'),
#  ('Hilton', 'male'),
#  ('Shelly', 'female'),
#  ('Sanson', 'male'),
#  ('Dustin', 'male'),
#  ('Genny', 'female'),
#  ('Randall', 'male'),
#  ('Luce', 'female'),
#  ('Erica', 'female'),
#  ('Suzzy', 'female'),
#  ('Myrle', 'female'),
#  ('Marjory', 'female'),
#  ('Jon', 'male'),
#  ('Russ', 'male'),
#  ('Pen', 'female'),
#  ('Chandra', 'female'),
#  ('Janith', 'female'),
#  ('Birgit', 'female'),
#  ('Purcell', 'male'),
#  ('Josephina', 'female'),
#  ('Concettina', 'female'),
#  ('Con', 'female'),
#  ('Fianna', 'female'),
#  ('Phaedra', 'female'),
#  ('Ulrick', 'male'),
#  ('Ginger', 'female'),
#  ('Monty', 'male'),
#  ('Jesus', 'male'),
#  ('Katherine', 'female'),
#  ('Othello', 'male'),
#  ('Aida', 'female'),
#  ('Wilow', 'female'),
#  ('Chantalle', 'female'),
#  ('Meridith', 'female'),
#  ('Marlane', 'female'),
#  ('Eddy', 'male'),
#  ('Trixi', 'female'),
#  ('Malcah', 'female'),
#  ('Iago', 'male'),
#  ('Ritch', 'male'),
#  ('Roseline', 'female'),
#  ('Clio', 'female'),
#  ('Roselin', 'female'),
#  ('Lilyan', 'female'),
#  ('Kaila', 'female'),
#  ('Dominique', 'female'),
#  ('Darb', 'female'),
#  ('Antonius', 'male'),
#  ('Susie', 'female'),
#  ('Guendolen', 'female'),
#  ('Charlie', 'male'),
#  ('Eugen', 'male'),
#  ('Ameline', 'female'),
#  ('Elianora', 'female'),
#  ('Irina', 'female'),
#  ('Diena', 'female'),
#  ('Oneida', 'female'),
#  ('Corwin', 'male'),
#  ('Danette', 'female'),
#  ('Lazare', 'male'),
#  ('Penni', 'female'),
#  ('Frances', 'female'),
#  ('Catie', 'female'),
#  ('Eba', 'female'),
#  ('Rice', 'male'),
#  ('Reba', 'female'),
#  ('Er', 'male'),
#  ('Harvey', 'male'),
#  ('Dani', 'female'),
#  ('Anneliese', 'female'),
#  ('Jean-Christophe', 'male'),
#  ('Josy', 'female'),
#  ('Ellyn', 'female'),
#  ('Rosie', 'female'),
#  ('Aline', 'female'),
#  ('Luci', 'female'),
#  ('Murray', 'male'),
#  ('Andria', 'female'),
#  ('Muire', 'female'),
#  ('Jacquelin', 'female'),
#  ('Robinia', 'female'),
#  ('Menard', 'male'),
#  ('Olympie', 'female'),
#  ('Krista', 'female'),
#  ('Rex', 'male'),
#  ('Minny', 'female'),
#  ('Dove', 'female'),
#  ('Ede', 'female'),
#  ('Licha', 'female'),
#  ('Marilee', 'female'),
#  ('Gillan', 'female'),
#  ('Mirabella', 'female'),
#  ('Filipe', 'male'),
#  ('Beulah', 'female'),
#  ('Reza', 'male'),
#  ('Vivi', 'female'),
#  ('Muffin', 'female'),
#  ('Jordain', 'female'),
#  ('Alix', 'male'),
#  ('Harold', 'male'),
#  ('Alejandro', 'male'),
#  ('Lisetta', 'female'),
#  ('Erda', 'female'),
#  ('Mariana', 'female'),
#  ('Clinton', 'male'),
#  ('Odell', 'male'),
#  ('Bertha', 'female'),
#  ('Janet', 'female'),
#  ('Gleda', 'female'),
#  ('Lorain', 'female'),
#  ('Gerianne', 'female'),
#  ('Jobye', 'female'),
#  ('Tessa', 'female'),
#  ('Jania', 'female'),
#  ('Elliott', 'male'),
#  ('Germana', 'female'),
#  ('Hebert', 'male'),
#  ('Roarke', 'male'),
#  ('Vernen', 'male'),
#  ('Amie', 'female'),
#  ('Maisie', 'female'),
#  ('Conan', 'male'),
#  ('Casper', 'male'),
#  ('Bharat', 'male'),
#  ('Rosaline', 'female'),
#  ('Tomi', 'female'),
#  ('Franklin', 'male'),
#  ('Sianna', 'female'),
#  ('Charmine', 'female'),
#  ('Kourtney', 'female'),
#  ('Marigold', 'female'),
#  ('Kelci', 'female'),
#  ('Jewell', 'female'),
#  ('Hastings', 'male'),
#  ('Cate', 'female'),
#  ('Townsend', 'male'),
#  ('Benny', 'male'),
#  ('Lesli', 'female'),
#  ('Raleigh', 'male'),
#  ('Zonda', 'female'),
#  ('Lina', 'female'),
#  ('Beverly', 'female'),
#  ('Gill', 'male'),
#  ('Syd', 'male'),
#  ('Oralie', 'female'),
#  ('Shina', 'female'),
#  ('Kippy', 'female'),
#  ('Kenny', 'male'),
#  ('Imogene', 'female'),
#  ('Sheela', 'female'),
#  ('Bernelle', 'female'),
#  ('Izzy', 'male'),
#  ('Garcia', 'male'),
#  ('Cris', 'male'),
#  ('Viole', 'female'),
#  ('Deloria', 'female'),
#  ('Julie', 'female'),
#  ('Tadeas', 'male'),
#  ('Guglielma', 'female'),
#  ('Hertha', 'female'),
#  ('Sig', 'male'),
#  ('Elena', 'female'),
#  ('Babita', 'female'),
#  ('Giavani', 'male'),
#  ('Sylvie', 'female'),
#  ('Rianon', 'female'),
#  ('Walther', 'male'),
#  ('Witold', 'male'),
#  ('Yale', 'male'),
#  ('Indira', 'female'),
#  ('Michele', 'male'),
#  ('Walt', 'male'),
#  ('Mortimer', 'male'),
#  ('Molly', 'female'),
#  ('Kitti', 'female'),
#  ('Lorene', 'female'),
#  ('Bary', 'male'),
#  ('Avrit', 'female'),
#  ('Kamilah', 'female'),
#  ('Kin', 'male'),
#  ('Hirsch', 'male'),
#  ('Ibrahim', 'male'),
#  ('Silvain', 'male'),
#  ('Rodolfo', 'male'),
#  ('Lonnie', 'female'),
#  ('Aleecia', 'female'),
#  ('Jephthah', 'male'),
#  ('Hammad', 'male'),
#  ('Ferd', 'male'),
#  ('Estrellita', 'female'),
#  ('Brenda', 'female'),
#  ('Neile', 'female'),
#  ('Clementia', 'female'),
#  ('Camella', 'female'),
#  ('Lesley', 'male'),
#  ('Emery', 'male'),
#  ('Roice', 'male'),
#  ('Tuck', 'male'),
#  ('Guillermo', 'male'),
#  ('Baillie', 'male'),
#  ('Natala', 'female'),
#  ('Donal', 'male'),
#  ('Herman', 'male'),
#  ('Melodie', 'female'),
#  ('Patricio', 'male'),
#  ('Teodora', 'female'),
#  ('Barr', 'male'),
#  ('Zsazsa', 'female'),
#  ('Stephan', 'male'),
#  ('Emmery', 'male'),
#  ('Bard', 'male'),
#  ('Horatia', 'female'),
#  ('Haskell', 'male'),
#  ('Marne', 'female'),
#  ('Nerita', 'female'),
#  ('Caressa', 'female'),
#  ('Janette', 'female'),
#  ('Rozamond', 'female'),
#  ('Anna-Diane', 'female'),
#  ('Harris', 'male'),
#  ('Aina', 'female'),
#  ('Orlando', 'male'),
#  ('Charley', 'male'),
#  ('Ward', 'male'),
#  ('Patsy', 'female'),
#  ('Kiah', 'female'),
#  ('Leena', 'female'),
#  ('Cecilia', 'female'),
#  ('Roxana', 'female'),
#  ('Elnore', 'female'),
#  ('Nev', 'male'),
#  ('Jannelle', 'female'),
#  ('Crystal', 'female'),
#  ('Dulcy', 'female'),
#  ('Melba', 'female'),
#  ('Hadleigh', 'male'),
#  ('Elise', 'female'),
#  ('Lorelle', 'female'),
#  ('Reina', 'female'),
#  ('Bronson', 'male'),
#  ('Vergil', 'male'),
#  ('Linnell', 'female'),
#  ('Yetta', 'female'),
#  ('Steffie', 'female'),
#  ('Gina', 'female'),
#  ('Fernande', 'female'),
#  ('Elwood', 'male'),
#  ('Rhody', 'female'),
#  ('Cristie', 'female'),
#  ('Jojo', 'female'),
#  ('Ingelbert', 'male'),
#  ('Brett', 'male'),
#  ('Nadiya', 'female'),
#  ('Bo', 'male'),
#  ('Frederic', 'male'),
#  ('Nicholas', 'male'),
#  ('Lon', 'male'),
#  ('Bartlet', 'male'),
#  ('Ulla', 'female'),
#  ('Cissy', 'female'),
#  ('Tracie', 'male'),
#  ('Annadiana', 'female'),
#  ('Teador', 'male'),
#  ('Prudence', 'female'),
#  ('Hilliard', 'male'),
#  ('Napoleon', 'male'),
#  ('Morse', 'male'),
#  ('Hagan', 'male'),
#  ('Broderick', 'male'),
#  ('Tiffy', 'female'),
#  ('Bria', 'female'),
#  ('Janey', 'female'),
#  ('Crysta', 'female'),
#  ('Jaine', 'female'),
#  ('Odysseus', 'male'),
#  ('Hilarie', 'female'),
#  ('Darcey', 'female'),
#  ('Win', 'male'),
#  ('Clement', 'male'),
#  ('Kaleb', 'male'),
#  ('Delcine', 'female'),
#  ('Janeen', 'female'),
#  ('Fatima', 'female'),
#  ('Evy', 'female'),
#  ('Carey', 'female'),
#  ('Marj', 'female'),
#  ('Si', 'male'),
#  ('Levy', 'male'),
#  ('Hagen', 'male'),
#  ('Bobine', 'female'),
#  ('Sheena', 'female'),
#  ('Ike', 'male'),
#  ('Yank', 'male'),
#  ('Arlana', 'female'),
#  ('Rochette', 'female'),
#  ('Ambrosius', 'male'),
#  ('Daniele', 'female'),
#  ('Kendra', 'female'),
#  ('Bogart', 'male'),
#  ('Analise', 'female'),
#  ('Leonidas', 'male'),
#  ('Katee', 'female'),
#  ('Lynette', 'female'),
#  ('Frayda', 'female'),
#  ('Spense', 'male'),
#  ('Clementine', 'female'),
#  ('Corry', 'female'),
#  ('Allys', 'female'),
#  ('Lauren', 'male'),
#  ('Huntley', 'male'),
#  ('Irving', 'male'),
#  ('Basil', 'male'),
#  ('Casi', 'female'),
#  ('Lancelot', 'male'),
#  ('Cammie', 'female'),
#  ('Norbert', 'male'),
#  ('Lars', 'male'),
#  ('Jilly', 'female'),
#  ('Vicky', 'female'),
#  ('Haydon', 'male'),
#  ('Mira', 'female'),
#  ('Cherice', 'female'),
#  ('Marlee', 'female'),
#  ('Lynna', 'female'),
#  ('Freddy', 'female'),
#  ('Andrea', 'male'),
#  ('Sosanna', 'female'),
#  ('Hurley', 'male'),
#  ('Teodorico', 'male'),
#  ('Reg', 'male'),
#  ('Henriette', 'female'),
#  ('Lilith', 'female'),
#  ('Florrie', 'female'),
#  ('Dannie', 'female'),
#  ('Lindsey', 'female'),
#  ('Linnea', 'female'),
#  ('Winifield', 'male'),
#  ('Mahala', 'female'),
#  ('Gavra', 'female'),
#  ('Greta', 'female'),
#  ('Thalia', 'female'),
#  ('Jeb', 'male'),
#  ('Marv', 'male'),
#  ('Daune', 'female'),
#  ('Karoly', 'female'),
#  ('Laurella', 'female'),
#  ('Polly', 'female'),
#  ('Irwin', 'male'),
#  ('Anallise', 'female'),
#  ('Diane-Marie', 'female'),
#  ('Phyllys', 'female'),
#  ('Matty', 'male'),
#  ('Carmon', 'female'),
#  ('Dorine', 'female'),
#  ('Mitchael', 'male'),
#  ('Norton', 'male'),
#  ('Alena', 'female'),
#  ('Mitchell', 'male'),
#  ('Jasmin', 'female'),
#  ('Elsi', 'female'),
#  ('Nikolia', 'female'),
#  ('Bill', 'male'),
#  ('Rudd', 'male'),
#  ('Evangeline', 'female'),
#  ('Kendrick', 'male'),
#  ('Dodie', 'female'),
#  ('Lucine', 'female'),
#  ('Flossie', 'female'),
#  ('Caterina', 'female'),
#  ('Cornela', 'female'),
#  ('Tulley', 'male'),
#  ('Alford', 'male'),
#  ('Kerrin', 'female'),
#  ('Ermentrude', 'female'),
#  ('Abbe', 'female'),
#  ('Godard', 'male'),
#  ('Jolie', 'female'),
#  ('Mitzi', 'female'),
#  ('Gabriel', 'female'),
#  ('Adorne', 'female'),
#  ('Enrichetta', 'female'),
#  ('Maurene', 'female'),
#  ('Edeline', 'female'),
#  ('Cariotta', 'female'),
#  ('Michele', 'female'),
#  ('Janaye', 'female'),
#  ('Gizela', 'female'),
#  ('Lilias', 'female'),
#  ('Gregor', 'male'),
#  ('Louella', 'female'),
#  ('Raychel', 'female'),
#  ('Gae', 'female'),
#  ('Dominique', 'male'),
#  ('Blinni', 'female'),
#  ('Sky', 'male'),
#  ('Erminie', 'female'),
#  ('Joshua', 'male'),
#  ('Idell', 'female'),
#  ('Rosemarie', 'female'),
#  ('Aldric', 'male'),
#  ('Hermann', 'male'),
#  ('Trace', 'male'),
#  ('Ramona', 'female'),
#  ('Milt', 'male'),
#  ('Julina', 'female'),
#  ('Myna', 'female'),
#  ('Lonee', 'female'),
#  ('Byron', 'male'),
#  ('Hallam', 'male'),
#  ('Fran', 'male'),
#  ('Carroll', 'male'),
#  ('Antonie', 'female'),
#  ('Mindy', 'female'),
#  ('Silvio', 'male'),
#  ('Doralynn', 'female'),
#  ('Juergen', 'male'),
#  ('Suzanne', 'female'),
#  ('Percival', 'male'),
#  ('Jolene', 'female'),
#  ('Stafford', 'male'),
#  ('Johanna', 'female'),
#  ('Burke', 'male'),
#  ('Dulci', 'female'),
#  ('Corrie', 'male'),
#  ('Michal', 'male'),
#  ('Meryl', 'male'),
#  ('Wilona', 'female'),
#  ('Elvira', 'female'),
#  ('Flossy', 'female'),
#  ('Caspar', 'male'),
#  ('Ragnar', 'male'),
#  ('Jaquith', 'female'),
#  ('Hana', 'female'),
#  ('Bernadette', 'female'),
#  ('Costa', 'male'),
#  ('Ulric', 'male'),
#  ('Pauletta', 'female'),
#  ('Cleva', 'female'),
#  ('Harriett', 'female'),
#  ('Vanya', 'female'),
#  ('Konstance', 'female'),
#  ('Lelah', 'female'),
#  ('Fancy', 'female'),
#  ('Emeline', 'female'),
#  ('Vivianne', 'female'),
#  ('Christine', 'female'),
#  ('Adger', 'male'),
#  ('Helene', 'female'),
#  ('Lilas', 'female'),
#  ('Francesca', 'female'),
#  ('Ortensia', 'female'),
#  ('Annalena', 'female'),
#  ('Genni', 'female'),
#  ('Ange', 'female'),
#  ('Tymon', 'male'),
#  ('Shay', 'male'),
#  ('Del', 'female'),
#  ('Alene', 'female'),
#  ('Bonny', 'female'),
#  ('Henryetta', 'female'),
#  ('Leah', 'female'),
#  ('Eolande', 'female'),
#  ('Gilles', 'male'),
#  ('Jacklyn', 'female'),
#  ('Shannah', 'female'),
#  ('Nerissa', 'female'),
#  ('Chrysler', 'female'),
#  ('Collete', 'female'),
#  ('Abbott', 'male'),
#  ('Bubba', 'male'),
#  ('Obadias', 'male'),
#  ('Meagan', 'female'),
#  ('Inessa', 'female'),
#  ('Trevar', 'male'),
#  ('Dulcia', 'female'),
#  ('Kip', 'female'),
#  ('Adelaide', 'female'),
#  ('Georgianne', 'female'),
#  ('Arther', 'male'),
#  ('Alex', 'female'),
#  ('Thorndike', 'male'),
#  ('Jerrome', 'male'),
#  ('Stig', 'male'),
#  ('Giraud', 'male'),
#  ('Martainn', 'male'),
#  ('Ester', 'female'),
#  ('Stepha', 'female'),
#  ('Henri', 'male'),
#  ('Galina', 'female'),
#  ('Cinnamon', 'female'),
#  ('Wileen', 'female'),
#  ('Brooks', 'male'),
#  ('Rupert', 'male'),
#  ('Davida', 'female'),
#  ('Gifford', 'male'),
#  ('Trixie', 'female'),
#  ('Manda', 'female'),
#  ('Tiffie', 'female'),
#  ('Cassi', 'female'),
#  ('Kimmy', 'female'),
#  ('Farley', 'male'),
#  ('Tony', 'female'),
#  ('Pauli', 'female'),
#  ('Ruthi', 'female'),
#  ('Cassandre', 'female'),
#  ('Adeline', 'female'),
#  ('Pammi', 'female'),
#  ('Adriane', 'female'),
#  ('Candi', 'female'),
#  ('Antoni', 'male'),
#  ('Lyda', 'female'),
#  ('Yehudit', 'female'),
#  ('Madelyn', 'female'),
#  ('Rees', 'male'),
#  ('Sheelagh', 'female'),
#  ('Marissa', 'female'),
#  ('Shawn', 'male'),
#  ('Kermie', 'male'),
#  ('Louis', 'male'),
#  ('Corissa', 'female'),
#  ('Lorilyn', 'female'),
#  ('Lem', 'male'),
#  ('Marcy', 'female'),
#  ('Ugo', 'male'),
#  ('Anna-Diana', 'female'),
#  ('Valeria', 'female'),
#  ('Robbert', 'male'),
#  ('Nadean', 'female'),
#  ('Gilbert', 'male'),
#  ('Lana', 'female'),
#  ('Gail', 'male'),
#  ('Ezekiel', 'male'),
#  ('Hazel', 'male'),
#  ('Christof', 'male'),
#  ('Lavina', 'female'),
#  ('Earle', 'male'),
#  ('Maurine', 'female'),
#  ('Patience', 'female'),
#  ('Ricky', 'female'),
#  ('Margit', 'female'),
#  ('Nan', 'female'),
#  ('Dulcine', 'female'),
#  ('Clarine', 'female'),
#  ('Pearle', 'female'),
#  ('Fabrice', 'female'),
#  ('Clyde', 'male'),
#  ('Kandy', 'female'),
#  ('Lothar', 'male'),
#  ('Ronna', 'female'),
#  ('Ardyth', 'female'),
#  ('Cari', 'female'),
#  ('Tamera', 'female'),
#  ('Trent', 'male'),
#  ('Gisella', 'female'),
#  ('Winifred', 'female'),
#  ('Irita', 'female'),
#  ('Harriet', 'female'),
#  ('Wendeline', 'female'),
#  ('Immanuel', 'male'),
#  ('Zara', 'female'),
#  ('Selena', 'female'),
#  ('Roddie', 'male'),
#  ('Junie', 'female'),
#  ('Jenica', 'female'),
#  ('Bela', 'male'),
#  ('Cristen', 'female'),
#  ('Marven', 'male'),
#  ('Etty', 'female'),
#  ('Mahmoud', 'male'),
#  ('Ardath', 'female'),
#  ('Claus', 'male'),
#  ('Sophia', 'female'),
#  ('Sanford', 'male'),
#  ('Derk', 'male'),
#  ('Berni', 'female'),
#  ('Errol', 'male'),
#  ('Zoe', 'female'),
#  ('Lauryn', 'female'),
#  ('Fox', 'male'),
#  ('Denna', 'female'),
#  ('Traver', 'male'),
#  ('Barbe', 'female'),
#  ('Florence', 'female'),
#  ('Delilah', 'female'),
#  ('Moselle', 'female'),
#  ('Ella', 'female'),
#  ('Catrina', 'female'),
#  ('Isadora', 'female'),
#  ('Milzie', 'female'),
#  ('Piet', 'male'),
#  ('Bertrand', 'male'),
#  ('Leonid', 'male'),
#  ('Piotr', 'male'),
#  ('Russel', 'male'),
#  ('Valene', 'female'),
#  ('Miran', 'female'),
#  ('Dorolice', 'female'),
#  ('Phillie', 'female'),
#  ('Ioana', 'female'),
#  ('Munmro', 'male'),
#  ('Debor', 'female'),
#  ('Kia', 'female'),
#  ('Abra', 'female'),
#  ('Darrell', 'male'),
#  ('Anett', 'female'),
#  ('Jere', 'female'),
#  ('Lucita', 'female'),
#  ('Harvie', 'male'),
#  ('Orville', 'male'),
#  ('Libbie', 'female'),
#  ('Bengt', 'male'),
#  ('Faythe', 'female'),
#  ('Cleo', 'female'),
#  ('Tammara', 'female'),
#  ('Heywood', 'male'),
#  ('Agretha', 'female'),
#  ('Daniel', 'male'),
#  ('Devan', 'female'),
#  ('Bel', 'female'),
#  ('Selle', 'female'),
#  ('Norah', 'female'),
#  ('Barron', 'male'),
#  ('Leonhard', 'male'),
#  ('Wald', 'male'),
#  ('Adriena', 'female'),
#  ('Maegan', 'female'),
#  ('Emmalynne', 'female'),
#  ('Hashim', 'male'),
#  ('Fan', 'female'),
#  ('Ellissa', 'female'),
#  ('Nannette', 'female'),
#  ('Violette', 'female'),
#  ('Anthony', 'male'),
#  ('Sena', 'female'),
#  ('Jessie', 'male'),
#  ('Conni', 'female'),
#  ('Tracy', 'female'),
#  ('Chloe', 'female'),
#  ('Nataline', 'female'),
#  ('Chanderjit', 'male'),
#  ('Tybie', 'female'),
#  ('Fons', 'male'),
#  ('Wendall', 'male'),
#  ('Dimitris', 'male'),
#  ('Blanca', 'female'),
#  ('Talya', 'female'),
#  ('Emyle', 'female'),
#  ('Etienne', 'male'),
#  ('Nahum', 'male'),
#  ('Mariel', 'female'),
#  ('Oona', 'female'),
#  ('Marshal', 'male'),
#  ('Geri', 'female'),
#  ('Craig', 'male'),
#  ('Lynelle', 'female'),
#  ('Lidia', 'female'),
#  ('Eugene', 'male'),
#  ('Darren', 'male'),
#  ('Beale', 'male'),
#  ('Worthy', 'male'),
#  ('Gillian', 'female'),
#  ('Ismail', 'male'),
#  ('Nancey', 'female'),
#  ('Quillan', 'male'),
#  ('Anatollo', 'male'),
#  ('Demetra', 'female'),
#  ('Maximilian', 'male'),
#  ('Wolf', 'male'),
#  ('Marcus', 'male'),
#  ('Erena', 'female'),
#  ('Simonne', 'female'),
#  ('Maggi', 'female'),
#  ('Bettye', 'female'),
#  ('Minerva', 'female'),
#  ('Vinnie', 'female'),
#  ('Eula', 'female'),
#  ('Mac', 'male'),
#  ('Randolf', 'male'),
#  ('Micaela', 'female'),
#  ('Tamar', 'female'),
#  ('Orbadiah', 'male'),
#  ('Bunnie', 'female'),
#  ('Silvester', 'male'),
#  ('Clemente', 'male'),
#  ('Athena', 'female'),
#  ('Myke', 'male'),
#  ('Sallee', 'female'),
#  ('Maisey', 'female'),
#  ('Koralle', 'female'),
#  ('Hildagarde', 'female'),
#  ('Amalee', 'female'),
#  ('Georgena', 'female'),
#  ('Rodger', 'male'),
#  ('Sallyanne', 'female'),
#  ('Nathanael', 'male'),
#  ('Herby', 'male'),
#  ('Chastity', 'female'),
#  ('Shayla', 'female'),
#  ('Cal', 'female'),
#  ('Martynne', 'female'),
#  ('Nady', 'female'),
#  ('Jaclin', 'female'),
#  ('Antonetta', 'female'),
#  ('Terza', 'female'),
#  ('Florian', 'male'),
#  ('Jessie', 'female'),
#  ('Rad', 'male'),
#  ('Amandi', 'female'),
#  ('Xaviera', 'female'),
#  ('Herold', 'male'),
#  ('Forbes', 'male'),
#  ('Graham', 'male'),
#  ('Alicea', 'female'),
#  ('Janifer', 'female'),
#  ('Padraig', 'male'),
#  ('Ferguson', 'male'),
#  ('Laraine', 'female'),
#  ('Pepillo', 'male'),
#  ('Lainey', 'female'),
#  ('Shannon', 'female'),
#  ('Ev', 'male'),
#  ('Grace', 'male'),
#  ('Suzie', 'female'),
#  ('Linus', 'male'),
#  ('Emlynn', 'female'),
#  ('Deonne', 'female'),
#  ('Hewet', 'male'),
#  ('Luanna', 'female'),
#  ('Constantin', 'male'),
#  ('Hall', 'male'),
#  ('Dwain', 'male'),
#  ('Mora', 'female'),
#  ('Sonja', 'female'),
#  ('Pet', 'female'),
#  ('Jenn', 'female'),
#  ('Lissa', 'female'),
#  ('Claudina', 'female'),
#  ('Robenia', 'female'),
#  ('Adrien', 'female'),
#  ('Yolanthe', 'female'),
#  ('Cherise', 'female'),
#  ('Margarette', 'female'),
#  ('Alastair', 'male'),
#  ('Ransom', 'male'),
#  ('Margi', 'female'),
#  ('Shilpa', 'female'),
#  ('Pinchas', 'male'),
#  ('Kara-Lynn', 'female'),
#  ('Fonz', 'male'),
#  ('Agace', 'female'),
#  ('Leta', 'female'),
#  ('Liorah', 'female'),
#  ('Hyacinthie', 'female'),
#  ('Brendan', 'male'),
#  ('Brant', 'male'),
#  ('Mariejeanne', 'female'),
#  ('Helen', 'female'),
#  ('Faith', 'female'),
#  ('Jackelyn', 'female'),
#  ('Cordelie', 'female'),
#  ('Goldarina', 'female'),
#  ('Nessie', 'female'),
#  ('Cristabel', 'female'),
#  ('Cyrill', 'male'),
#  ('Wait', 'male'),
#  ('Brandy', 'female'),
#  ('Allis', 'female'),
#  ('Stefa', 'female'),
#  ('Diamond', 'female'),
#  ('Hyacintha', 'female'),
#  ('Samara', 'female'),
#  ('Cosette', 'female'),
#  ('Maxi', 'female'),
#  ('Sigfried', 'male'),
#  ('Roberta', 'female'),
#  ('Colbert', 'male'),
#  ('Ame', 'female'),
#  ('Pamella', 'female'),
#  ('Letti', 'female'),
#  ('Malinda', 'female'),
#  ('Kial', 'female'),
#  ('Johann', 'male'),
#  ('Arda', 'female'),
#  ('Gipsy', 'female'),
#  ('Chris', 'male'),
#  ('Clementina', 'female'),
#  ('Rhetta', 'female'),
#  ('Janot', 'female'),
#  ('Eddie', 'female'),
#  ('Marabel', 'female'),
#  ('Gerome', 'male'),
#  ('Blondell', 'female'),
#  ('Gerty', 'female'),
#  ('Stillman', 'male'),
#  ('Raye', 'female'),
#  ('Abigail', 'female'),
#  ('Lew', 'male'),
#  ('Normie', 'male'),
#  ('Orson', 'male'),
#  ('Ruthy', 'female'),
#  ('Raphaela', 'female'),
#  ('Joelle', 'female'),
#  ('Willmott', 'male'),
#  ('Broddie', 'male'),
#  ...]
